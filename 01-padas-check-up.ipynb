# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/olegyarygin/Pandas/Dataset/aug_train.csv")

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Основные информации с DataFrame

# %%
len(df)
# Out:
# 2129

# %%
df.head(3)
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# 2              NaN         <1          NaN      Pvt Ltd        never
#
#    training_hours
# 0              21
# 1              98
# 2              15

# %%
df["city"]
# Out:
# 0        city_41
# 1       city_103
# 2        city_21
# 3        city_13
# 4       city_103
#           ...
# 2124    city_103
# 2125    city_136
# 2126    city_100
# 2127    city_102
# 2128    city_102
# Name: city, Length: 2129, dtype: object

# %%
df[["city"]]
# Out:
#           city
# 0      city_41
# 1     city_103
# 2      city_21
# 3      city_13
# 4     city_103
# ...        ...
# 2124  city_103
# 2125  city_136
# 2126  city_100
# 2127  city_102
# 2128  city_102
#
# [2129 rows x 1 columns]

# %%
df[["city","city_development_index"]]
# Out:
#           city  city_development_index
# 0      city_41                   0.827
# 1     city_103                   0.920
# 2      city_21                   0.624
# 3      city_13                   0.827
# 4     city_103                   0.920
# ...        ...                     ...
# 2124  city_103                   0.920
# 2125  city_136                   0.897
# 2126  city_100                   0.887
# 2127  city_102                   0.804
# 2128  city_102                   0.804
#
# [2129 rows x 2 columns]

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
df = df.drop("city", axis=1) # Убираем по оси Y - столбик City (Inplace)

# %%
df.columns # Получение списка всех столбцов
# Out:
# Index(['enrollee_id', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours'],
#       dtype='object')

# %%
df[['enrollee_id', 'company_type',
       'last_new_job', 'training_hours']]
# Out:
#       enrollee_id   company_type last_new_job  training_hours
# 0           32403            NaN            1              21
# 1            9858        Pvt Ltd            1              98
# 2           31806        Pvt Ltd        never              15
# 3           27385        Pvt Ltd            1              39
# 4           27724        Pvt Ltd           >4              72
# ...           ...            ...          ...             ...
# 2124         1289  Public Sector            4              15
# 2125          195            NaN            2              30
# 2126        31762        Pvt Ltd        never              18
# 2127         7873  Public Sector            1              84
# 2128        12215        Pvt Ltd            2              11
#
# [2129 rows x 4 columns]

# %%
df["new_column"] = 1 # Добавление нового столбца и константы

# %%
df["new_col_tree"] = df["training_hours"] / 3

# %%
df
# Out:
#       enrollee_id  city_development_index  gender      relevent_experience  \
# 0           32403                   0.827    Male  Has relevent experience
# 1            9858                   0.920  Female  Has relevent experience
# 2           31806                   0.624    Male   No relevent experience
# 3           27385                   0.827    Male  Has relevent experience
# 4           27724                   0.920    Male  Has relevent experience
# ...           ...                     ...     ...                      ...
# 2124         1289                   0.920    Male   No relevent experience
# 2125          195                   0.897    Male  Has relevent experience
# 2126        31762                   0.887    Male   No relevent experience
# 2127         7873                   0.804    Male  Has relevent experience
# 2128        12215                   0.804    Male  Has relevent experience
#
# ...

# %%
df.assign(new_columnn=3) # Действие происходит в момент (Для вспомогательных стобцов)
# Out:
#       enrollee_id  city_development_index  gender      relevent_experience  \
# 0           32403                   0.827    Male  Has relevent experience
# 1            9858                   0.920  Female  Has relevent experience
# 2           31806                   0.624    Male   No relevent experience
# 3           27385                   0.827    Male  Has relevent experience
# 4           27724                   0.920    Male  Has relevent experience
# ...           ...                     ...     ...                      ...
# 2124         1289                   0.920    Male   No relevent experience
# 2125          195                   0.897    Male  Has relevent experience
# 2126        31762                   0.887    Male   No relevent experience
# 2127         7873                   0.804    Male  Has relevent experience
# 2128        12215                   0.804    Male  Has relevent experience
#
# ...

# %% [markdown]
# # Фильтрация и сортировка

# %%
df[df["city"] == "city_40"] # pandas notation
# Out:
#       enrollee_id     city  city_development_index  gender  \
# 300          8485  city_40                   0.776    Male
# 925         13467  city_40                   0.776    Male
# 1024        31984  city_40                   0.776    Male
# 1035         3413  city_40                   0.776     NaN
# 1305        32693  city_40                   0.776    Male
# 1455        15682  city_40                   0.776  Female
# 1494        25679  city_40                   0.776    Male
# 1528         7789  city_40                   0.776     NaN
# 1572         9556  city_40                   0.776     NaN
# 1800         2789  city_40                   0.776    Male
# 1810        30013  city_40                   0.776    Male
# 1896        22480  city_40                   0.776    Male
#
#           relevent_experience enrolled_university education_level  \
# 300    No relevent experience    Full time course        Graduate
# ...

# %%
df.query('city == "city_40"')
# Out:
#       enrollee_id     city  city_development_index  gender  \
# 300          8485  city_40                   0.776    Male
# 925         13467  city_40                   0.776    Male
# 1024        31984  city_40                   0.776    Male
# 1035         3413  city_40                   0.776     NaN
# 1305        32693  city_40                   0.776    Male
# 1455        15682  city_40                   0.776  Female
# 1494        25679  city_40                   0.776    Male
# 1528         7789  city_40                   0.776     NaN
# 1572         9556  city_40                   0.776     NaN
# 1800         2789  city_40                   0.776    Male
# 1810        30013  city_40                   0.776    Male
# 1896        22480  city_40                   0.776    Male
#
#           relevent_experience enrolled_university education_level  \
# 300    No relevent experience    Full time course        Graduate
# ...

# %%
df[(df["city"] == "city_40") & (df["education_level"] == "Graduate")]
# Out:
#       enrollee_id     city  city_development_index  gender  \
# 300          8485  city_40                   0.776    Male
# 925         13467  city_40                   0.776    Male
# 1455        15682  city_40                   0.776  Female
# 1528         7789  city_40                   0.776     NaN
# 1572         9556  city_40                   0.776     NaN
# 1800         2789  city_40                   0.776    Male
# 1896        22480  city_40                   0.776    Male
#
#           relevent_experience enrolled_university education_level  \
# 300    No relevent experience    Full time course        Graduate
# 925    No relevent experience       no_enrollment        Graduate
# 1455  Has relevent experience       no_enrollment        Graduate
# 1528  Has relevent experience    Part time course        Graduate
# 1572  Has relevent experience       no_enrollment        Graduate
# 1800  Has relevent experience       no_enrollment        Graduate
# ...

# %%
city_40_Male = df.query('city == "city_40"' and 'gender == "Male"').copy()

# %%
city_40_Male["new_colomn"] = 1

# %%
city_40_Male
# Out:
#       enrollee_id      city  city_development_index gender  \
# 0           32403   city_41                   0.827   Male
# 2           31806   city_21                   0.624   Male
# 3           27385   city_13                   0.827   Male
# 4           27724  city_103                   0.920   Male
# 5             217   city_23                   0.899   Male
# ...           ...       ...                     ...    ...
# 2124         1289  city_103                   0.920   Male
# 2125          195  city_136                   0.897   Male
# 2126        31762  city_100                   0.887   Male
# 2127         7873  city_102                   0.804   Male
# 2128        12215  city_102                   0.804   Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 2      No relevent experience       no_enrollment     High School
# ...

# %% [markdown]
# # Пропуски

# %%
df.isna().mean() # Доля незаполненных данных
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# gender                    0.238610
# relevent_experience       0.000000
# enrolled_university       0.014561
# education_level           0.024425
# major_discipline          0.146548
# experience                0.002349
# company_size              0.292156
# company_type              0.297792
# last_new_job              0.018788
# training_hours            0.000000
# dtype: float64

# %%
df.isna().mean().sort_values(ascending = False ) # Первая строчка самая большая доля ошибки (сортирована)
# Out:
# company_type              0.297792
# company_size              0.292156
# gender                    0.238610
# major_discipline          0.146548
# education_level           0.024425
# last_new_job              0.018788
# enrolled_university       0.014561
# experience                0.002349
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# relevent_experience       0.000000
# training_hours            0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.4+ KB

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# dtype: object

# %% [markdown]
# # Типы Данных

# %%
# Темная тема гистограмма 

import matplotlib.pyplot as plt
plt.style.use('dark_background')

df["city_development_index"].hist()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours
# count   2129.000000             2129.000000     2129.000000
# mean   16861.614843                0.824984       64.983091
# std     9576.846029                0.125074       60.238660
# min        3.000000                0.448000        1.000000
# 25%     8562.000000                0.698000       23.000000
# 50%    16816.000000                0.903000       47.000000
# 75%    25129.000000                0.920000       86.000000
# max    33353.000000                0.949000      334.000000

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      1460
# Female     137
# Other       24
# Name: count, dtype: int64

# %%
# Добавить пропуски
df["gender"].value_counts(dropna = False)
# Out:
# gender
# Male      1460
# NaN        508
# Female     137
# Other       24
# Name: count, dtype: int64

# %% [markdown]
# # Фильтрация по квантилю

# %%
q = df["city_development_index"].quantile(0.25)

# %%
df[df["city_development_index"] < q] # 25 % нашего dataset 450 записей
# Out:
#       enrollee_id     city  city_development_index  gender  \
# 2           31806  city_21                   0.624    Male
# 6           21465  city_21                   0.624     NaN
# 9           16287  city_21                   0.624    Male
# 15          24914  city_21                   0.624     NaN
# 16           7865  city_21                   0.624    Male
# ...           ...      ...                     ...     ...
# 2092        33290  city_21                   0.624     NaN
# 2093        27216  city_21                   0.624     NaN
# 2097        13464  city_21                   0.624    Male
# 2115        13833  city_21                   0.624    Male
# 2123        21339  city_21                   0.624  Female
#
#           relevent_experience enrolled_university education_level  \
# 2      No relevent experience       no_enrollment     High School
# 6     Has relevent experience       no_enrollment        Graduate
# ...

# %%
q = df["city_development_index"].quantile(0.05)

# %%
# Вся 
df["city_development_index"].hist()
# С условием
df[df["city_development_index"] >= q]["city_development_index"].hist()
# Out:
# <Axes: >

# %%
df[df["city_development_index"].between(q, 2)]["city_development_index"].hist()
# Out:
# <Axes: >
